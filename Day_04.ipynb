# %% [markdown]
# # Day 4 – Applied Python Problem Solving
# **Goal:** Strengthen logical thinking and apply Python in small real-world mini problems.
# **Focus Areas:** Data manipulation, file handling, OOP, algorithmic logic.

# %% [markdown]
# ## 1. Data Manipulation & Logic

# %% [markdown]
# **1.Write a program to find all pairs of numbers in a list whose sum equals a target value.
# Example: [1,2,3,4,5,6], target = 7 → pairs (1,6), (2,5), (3,4)**
